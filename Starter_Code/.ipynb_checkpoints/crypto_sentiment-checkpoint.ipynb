# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline

from newsapi import NewsApiClient
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Chris
# [nltk_data]     Chan\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")
type(api_key)
# Out:
# str

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(q="bitcoin", language="en")

# %%
# Fetch the Ethereum news articles
ethereum_headlines = newsapi.get_everything(q="Ethereum", language="en")

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_df = pd.DataFrame.from_dict(bitcoin_headlines["articles"])
bitcoin_df.head()
# Out:
#                                        source            author  \
# 0  {'id': 'techcrunch', 'name': 'TechCrunch'}      Alex Wilhelm
# 1  {'id': 'techcrunch', 'name': 'TechCrunch'}    Rebecca Bellan
# 2      {'id': None, 'name': 'Lifehacker.com'}      Mike Winters
# 3  {'id': 'techcrunch', 'name': 'TechCrunch'}      Lucas Matney
# 4  {'id': 'techcrunch', 'name': 'TechCrunch'}  Tage Kene-Okafor
#
#                                                title  \
# 0  What Square’s smashing earnings tell us about ...
# 1  Tesla sees bitcoin as important financial tool...
# 2  You Can Now Exchange Crypto on Venmo, If You'r...
# 3  Crypto market takes a dive with Bitcoin leadin...
# 4  African crypto usage spurs Luno as customers r...
#
#                                          description  \
# 0  Today we're talking Square earnings and its bi...
# 1  Tesla’s relationship with bitcoin is not a dal...
# 2  Cryptocurrency continues to gain mainstream ac...
# 3  Cryptocurrency prices continued to tumble Frid...
# 4  The crypto industry as a whole has seen a mome...
#
#                                                  url  \
# 0  http://techcrunch.com/2021/05/07/what-squares-...
# 1  http://techcrunch.com/2021/04/26/tesla-sees-bi...
# 2  https://twocents.lifehacker.com/you-can-now-ex...
# 3  http://techcrunch.com/2021/04/23/crypto-market...
# 4  http://techcrunch.com/2021/04/13/african-crypt...
#
#                                           urlToImage           publishedAt  \
# 0  https://techcrunch.com/wp-content/uploads/2020...  2021-05-07T18:17:36Z
# 1  https://techcrunch.com/wp-content/uploads/2021...  2021-04-27T01:36:46Z
# 2  https://i.kinja-img.com/gawker-media/image/upl...  2021-04-20T19:00:00Z
# 3  https://techcrunch.com/wp-content/uploads/2020...  2021-04-23T17:58:10Z
# 4  https://techcrunch.com/wp-content/uploads/2020...  2021-04-13T08:30:21Z
#
#                                              content
# 0  Shares of Square are up more than 6% today aft...
# 1  Tesla’s relationship with bitcoin is not a dal...
# 2  Cryptocurrency continues to gain mainstream ac...
# 3  Cryptocurrency prices continued to tumble Frid...
# 4  The crypto industry as a whole has seen a mome...

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_df = pd.DataFrame.from_dict(ethereum_headlines["articles"])
ethereum_df.head()
# Out:
#                                        source  \
# 0  {'id': 'techcrunch', 'name': 'TechCrunch'}
# 1      {'id': None, 'name': 'Lifehacker.com'}
# 2      {'id': 'mashable', 'name': 'Mashable'}
# 3                {'id': 'cnn', 'name': 'CNN'}
# 4  {'id': 'techcrunch', 'name': 'TechCrunch'}
#
#                             author  \
# 0                      David Riggs
# 1                     Mike Winters
# 2                   Stan Schroeder
# 3  Paul R. La Monica, CNN Business
# 4                     Lucas Matney
#
#                                                title  \
# 0  Radical Ethereum entrepreneurs are redefining ...
# 1  You Can Now Exchange Crypto on Venmo, If You'r...
# 2  Venmo now lets users buy and sell Bitcoin and ...
# 3  Move over, Bitcoin. Ethereum is at an all-time...
# 4  CryptoPunks maker Larva Labs launches their ne...
#
#                                          description  \
# 0  Their investors call them disruptive innovator...
# 1  Cryptocurrency continues to gain mainstream ac...
# 2  Venmo is jumping aboard the cryptocurrency ban...
# 3  Bitcoin prices continued their rebound Saturda...
# 4  The creators behind CryptoPunks, one of the mo...
#
#                                                  url  \
# 0  http://techcrunch.com/2021/05/04/radical-ether...
# 1  https://twocents.lifehacker.com/you-can-now-ex...
# 2         https://mashable.com/article/venmo-crypto/
# 3  https://www.cnn.com/2021/05/01/investing/ether...
# 4  http://techcrunch.com/2021/05/03/cryptopunks-m...
#
#                                           urlToImage           publishedAt  \
# 0  https://techcrunch.com/wp-content/uploads/2021...  2021-05-04T14:30:39Z
# 1  https://i.kinja-img.com/gawker-media/image/upl...  2021-04-20T19:00:00Z
# 2  https://mondrian.mashable.com/2021%252F04%252F...  2021-04-20T11:23:13Z
# 3  https://cdn.cnn.com/cnnnext/dam/assets/2105010...  2021-05-01T17:24:45Z
# 4  https://techcrunch.com/wp-content/uploads/2021...  2021-05-03T18:08:48Z
#
#                                              content
# 0  Their investors call them disruptive innovator...
# 1  Cryptocurrency continues to gain mainstream ac...
# 2  Venmo is jumping aboard the cryptocurrency ban...
# 3  New York (CNN Business)Bitcoin prices continue...
# 4  The creators behind CryptoPunks, one of the mo...

# %%
# Describe the Bitcoin Sentiment
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    result = 0  # Neutral by default
    if score >= 0.05:  # Positive
        result = 1
    elif score <= -0.05:  # Negative
        result = -1

    return result


bitcoin_text_sent = {
    "text_compound": [],
    "text_pos": [],
    "text_neu": [],
    "text_neg": [],
    "text_sent": [],
    "text_content": [],
}


for index, row in bitcoin_df.iterrows():
    try:
        # Sentiment scoring with VADER
        text_sentiment = analyzer.polarity_scores(row["content"])
        bitcoin_text_sent["text_compound"].append(text_sentiment["compound"])
        bitcoin_text_sent["text_pos"].append(text_sentiment["pos"])
        bitcoin_text_sent["text_neu"].append(text_sentiment["neu"])
        bitcoin_text_sent["text_neg"].append(text_sentiment["neg"])
        bitcoin_text_sent["text_sent"].append(get_sentiment(text_sentiment["compound"]))
        bitcoin_text_sent["text_content"].append(row["content"])       
    except AttributeError:
        pass

bitcoin_sentiment_df = pd.DataFrame(bitcoin_text_sent)
bitcoin_sentiment_df.describe()
# Out:
#        text_compound   text_pos   text_neu   text_neg  text_sent
# count      20.000000  20.000000  20.000000  20.000000  20.000000
# mean        0.204960   0.058650   0.931100   0.010300   0.400000
# std         0.310796   0.070231   0.078141   0.025375   0.598243
# min        -0.381800   0.000000   0.777000   0.000000  -1.000000
# 25%         0.000000   0.000000   0.857000   0.000000   0.000000
# 50%         0.012900   0.017000   0.954000   0.000000   0.000000
# 75%         0.360375   0.119250   1.000000   0.000000   1.000000
# max         0.750600   0.179000   1.000000   0.080000   1.000000

# %%
# Describe the Ethereum Sentiment

ethereum_text_sent = {
    "text_compound": [],
    "text_pos": [],
    "text_neu": [],
    "text_neg": [],
    "text_sent": [],
    "text_content": [],
}


for index, row in ethereum_df.iterrows():
    try:
        # Sentiment scoring with VADER
        text_sentiment = analyzer.polarity_scores(row["content"])
        ethereum_text_sent["text_compound"].append(text_sentiment["compound"])
        ethereum_text_sent["text_pos"].append(text_sentiment["pos"])
        ethereum_text_sent["text_neu"].append(text_sentiment["neu"])
        ethereum_text_sent["text_neg"].append(text_sentiment["neg"])
        ethereum_text_sent["text_sent"].append(get_sentiment(text_sentiment["compound"]))
        ethereum_text_sent["text_content"].append(row["content"])   
    except AttributeError:
        pass

ethereum_sentiment_df = pd.DataFrame(ethereum_text_sent)
ethereum_sentiment_df.describe()
# Out:
#        text_compound   text_pos   text_neu   text_neg  text_sent
# count      20.000000  20.000000  20.000000  20.000000  20.000000
# mean        0.120525   0.041850   0.948900   0.009250   0.300000
# std         0.285566   0.059469   0.064801   0.029097   0.656947
# min        -0.340000   0.000000   0.790000   0.000000  -1.000000
# 25%         0.000000   0.000000   0.924000   0.000000   0.000000
# 50%         0.000000   0.017000   0.964000   0.000000   0.000000
# 75%         0.164300   0.056000   1.000000   0.000000   1.000000
# max         0.817600   0.210000   1.000000   0.111000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
sw_addons = {'happy', 'dogecoin', 'elonmusk','investor'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
   
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw_addons)]
    
    # Remove the stop words
    
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_sentiment_df['tokens'] = bitcoin_sentiment_df.text_content.apply(tokenizer)
bitcoin_sentiment_df.head()
# Out:
#    text_compound  text_pos  text_neu  text_neg  text_sent  \
# 0         0.2960     0.058     0.942       0.0          1
# 1         0.0000     0.000     1.000       0.0          0
# 2         0.7506     0.171     0.829       0.0          1
# 3         0.0000     0.000     1.000       0.0          0
# 4         0.6124     0.135     0.865       0.0          1
#
#                                         text_content  \
# 0  Shares of Square are up more than 6% today aft...
# 1  Tesla’s relationship with bitcoin is not a dal...
# 2  Cryptocurrency continues to gain mainstream ac...
# 3  Cryptocurrency prices continued to tumble Frid...
# 4  The crypto industry as a whole has seen a mome...
#
#                                               tokens
# 0  [shares, square, today, american, fintech, com...
# 1  [teslas, relationship, bitcoin, dalliance, acc...
# 2  [cryptocurrency, continues, gain, mainstream, ...
# 3  [cryptocurrency, price, continued, tumble, fri...
# 4  [crypto, industry, whole, ha, seen, momentous,...

# %%
# Create a new tokens column for Ethereum
ethereum_sentiment_df['tokens'] = ethereum_sentiment_df.text_content.apply(tokenizer)
ethereum_sentiment_df.head()
# Out:
#    text_compound  text_pos  text_neu  text_neg  text_sent  \
# 0        -0.2144     0.054     0.835     0.111         -1
# 1         0.7506     0.171     0.829     0.000          1
# 2         0.0258     0.034     0.966     0.000          0
# 3         0.0000     0.000     1.000     0.000          0
# 4         0.4754     0.091     0.909     0.000          1
#
#                                         text_content  \
# 0  Their investors call them disruptive innovator...
# 1  Cryptocurrency continues to gain mainstream ac...
# 2  Venmo is jumping aboard the cryptocurrency ban...
# 3  New York (CNN Business)Bitcoin prices continue...
# 4  The creators behind CryptoPunks, one of the mo...
#
#                                               tokens
# 0  [call, disruptive, innovator, detractors, like...
# 1  [cryptocurrency, continues, gain, mainstream, ...
# 2  [venmo, jumping, aboard, cryptocurrency, bandw...
# 3  [new, york, cnn, businessbitcoin, price, conti...
# 4  [creator, behind, cryptopunks, one, popular, n...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
N = 2
grams = ngrams(tokenizer(bitcoin_sentiment_df.text_content.str.cat()), N)
Counter(grams).most_common(20)
# Out:
# [(('charsby', 'reuters'), 6),
#  (('said', 'monday'), 3),
#  (('price', 'continued'), 2),
#  (('ha', 'seen'), 2),
#  (('cryptocurrency', 'ha'), 2),
#  (('microstrategy', 'inc'), 2),
#  (('inc', 'major'), 2),
#  (('major', 'bitcoin'), 2),
#  (('bitcoin', 'corporate'), 2),
#  (('corporate', 'backer'), 2),
#  (('backer', 'said'), 2),
#  (('monday', 'nonemployee'), 2),
#  (('nonemployee', 'director'), 2),
#  (('director', 'get'), 2),
#  (('get', 'fee'), 2),
#  (('fee', 'service'), 2),
#  (('service', 'bitcoin'), 2),
#  (('bitcoin', 'instead'), 2),
#  (('reuters', 'staffapril'), 2),
#  (('staffapril', 'reuters'), 2)]

# %%
# Generate the Ethereum N-grams where N=2
N = 2
grams = ngrams(tokenizer(ethereum_sentiment_df.text_content.str.cat()), N)
Counter(grams).most_common(20)
# Out:
# [(('charsby', 'reuters'), 4),
#  (('representation', 'virtual'), 4),
#  (('virtual', 'currency'), 4),
#  (('currency', 'ethereum'), 4),
#  (('ethereum', 'seen'), 4),
#  (('seen', 'front'), 4),
#  (('front', 'stock'), 4),
#  (('stock', 'graph'), 4),
#  (('graph', 'illustration'), 4),
#  (('illustration', 'taken'), 4),
#  (('taken', 'february'), 4),
#  (('february', 'reutersdado'), 4),
#  (('bitcoin', 'ethereum'), 3),
#  (('ether', 'hit'), 3),
#  (('hit', 'record'), 3),
#  (('record', 'high'), 3),
#  (('may', 'reuters'), 3),
#  (('digital', 'currency'), 3),
#  (('charsnew', 'york'), 2),
#  (('reuters', 'stafffile'), 2)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
bitcion_tokens = tokenizer(bitcoin_sentiment_df.text_content.str.cat())
token_count(bitcion_tokens, 10)
# Out:
# [('bitcoin', 14),
#  ('reuters', 9),
#  ('ha', 7),
#  ('charsby', 6),
#  ('cryptocurrency', 5),
#  ('monday', 4),
#  ('price', 4),
#  ('service', 4),
#  ('said', 4),
#  ('coin', 3)]

# %%
# Use token_count to get the top 10 words for Ethereum
ethereum_tokens = tokenizer(ethereum_sentiment_df.text_content.str.cat())
token_count(ethereum_tokens, 10)
# Out:
# [('ethereum', 9),
#  ('reuters', 7),
#  ('currency', 7),
#  ('stock', 6),
#  ('bitcoin', 5),
#  ('cryptocurrency', 5),
#  ('ha', 5),
#  ('project', 4),
#  ('major', 4),
#  ('charsby', 4)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
bitcoin_wc = WordCloud().generate(bitcoin_sentiment_df.text_content.str.cat())
plt.imshow(bitcoin_wc)

# %%
# Generate the Ethereum word cloud
ethereum_wc = WordCloud().generate(ethereum_sentiment_df.text_content.str.cat())
plt.imshow(ethereum_wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
# YOUR CODE HERE!

# %%
# List all Entities
# YOUR CODE HERE!

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
# YOUR CODE HERE!

# %%
# List all Entities
# YOUR CODE HERE!

# %% [markdown]
# ---
